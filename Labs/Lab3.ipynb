# %%
import pandas as pd

# %%
data = pd.read_csv('../Data/us_equities.csv')

data.drop(['Unnamed: 0'], axis=1, inplace=True)
data["Missing Values"] = data.isnull().sum(axis=1)
display(data.head())
data["Missing Values"].plot()
# Out:
#    ^GSPC  GE  IBM  DIS  BA  CAT  AA  HPQ  DD  KO  ...  CTR  DYN  AIB  PCU  \
# 0  16.66 NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 1  16.85 NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 2  16.93 NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 3  16.98 NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 4  17.08 NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
#
#    KIM  SFN  AMR  TCO   S  Missing Values
# 0  NaN  NaN  NaN  NaN NaN            1052
# 1  NaN  NaN  NaN  NaN NaN            1052
# 2  NaN  NaN  NaN  NaN NaN            1052
# 3  NaN  NaN  NaN  NaN NaN            1052
# 4  NaN  NaN  NaN  NaN NaN            1052
#
# [5 rows x 1054 columns]
# <Axes: >

# %%
gspc_null = data[data["^GSPC"].isnull()]
display(gspc_null)
weird_assets = gspc_null.notnull().sum() > 1
display(weird_assets.drop(weird_assets == False))
# Out:
#        ^GSPC  GE  IBM  DIS  BA  CAT  AA  HPQ  DD  KO  ...  CTR  DYN  AIB  PCU  \
# 8008     NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 8979     NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 12594    NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 12619    NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 12663    NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# ...      ...  ..  ...  ...  ..  ...  ..  ...  ..  ..  ...  ...  ...  ...  ...
# 16212    NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 16231    NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 16236    NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 16249    NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
# 16269    NaN NaN  NaN  NaN NaN  NaN NaN  NaN NaN NaN  ...  NaN  NaN  NaN  NaN
#
# ...
